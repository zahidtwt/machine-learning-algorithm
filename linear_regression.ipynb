# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# Linear Regression Class Implementation
class LinearRegression:
    def fit(self, X, y):
        n = len(X)
        X_mean = np.mean(X)
        y_mean = np.mean(y)

        numerator = 0
        denominator = 0
        for i in range(n):
            numerator += (X[i] - X_mean) * (y[i] - y_mean)
            denominator += (X[i] - X_mean) ** 2

        self.coefficient = numerator / denominator # m = (x - x_mean) * (y - y_mean) / (x - x_mean) ** 2
        self.intercept = y_mean - (self.coefficient * X_mean)  # c = y_mean - m * x_mean

    def predict(self, X):
        print(self.coefficient, self.intercept)
        return self.coefficient * X + self.intercept # y = mx + c

# %%
X = np.random.rand(100, 1) * 10  # Generate 100 random values between 0 and 10 for X
y = 2 * X.squeeze() + np.random.randn(100) * 2  # Generate y values with noise

# %%
# Training the model
model = LinearRegression()
model.fit(X, y)

# %%
# Making predictions
y_pred = model.predict(X)
# Out:
# [2.07638513] [0.05069196]

# %%
# Plotting the data and best fit line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.show()
